# %%
import matplotlib.pyplot as plt
from keras.datasets import imdb
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN, Dense, LSTM, Bidirectional

# %%
max_features = 10000
maxlen = 500

# %%
(input_train, y_train), (input_test, y_test) = imdb.load_data(num_words=max_features)
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
input_train = pad_sequences(input_train, maxlen=maxlen)
input_test = pad_sequences(input_test, maxlen=maxlen)

# %%
model_rnn = Sequential()

model_rnn.add(Embedding(max_features, 32))
model_rnn.add(SimpleRNN(32))
model_rnn.add(Dense(1, activation='sigmoid'))

model_rnn.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history_rnn = model_rnn.fit(input_train, y_train, epochs=5, batch_size=128, validation_split=0.3)
# Out:
# Epoch 1/5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 26s 130ms/step - accuracy: 0.6684 - loss: 0.6033 - val_accuracy: 0.7633 - val_loss: 0.5023
# Epoch 2/5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - accuracy: 0.8153 - loss: 0.4226 - val_accuracy: 0.8120 - val_loss: 0.4264
# Epoch 3/5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 48ms/step - accuracy: 0.8699 - loss: 0.3155 - val_accuracy: 0.8497 - val_loss: 0.3653
# Epoch 4/5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 9s 65ms/step - accuracy: 0.9049 - loss: 0.2451 - val_accuracy: 0.8688 - val_loss: 0.3491
# Epoch 5/5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.9339 - loss: 0.1802 - val_accuracy: 0.8368 - val_loss: 0.4067

# %%
acc = history_rnn.history['accuracy']
val_acc = history_rnn.history['val_accuracy']
loss = history_rnn.history['loss']
val_loss = history_rnn.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')

plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')

plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
model_lstm = Sequential()

model_lstm.add(Embedding(max_features, 32))
model_lstm.add(LSTM(32))
model_lstm.add(Dense(1, activation='sigmoid'))

model_lstm.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history_ltsm = model_lstm.fit(input_train, y_train, epochs=5, batch_size=128, validation_split=0.3)
# Out:
# Epoch 1/5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.6451 - loss: 0.6263 - val_accuracy: 0.6217 - val_loss: 0.6511
# Epoch 2/5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.8161 - loss: 0.4208 - val_accuracy: 0.8000 - val_loss: 0.4399
# Epoch 3/5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8591 - loss: 0.3468 - val_accuracy: 0.8116 - val_loss: 0.4561
# Epoch 4/5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.8750 - loss: 0.3137 - val_accuracy: 0.8629 - val_loss: 0.3218
# Epoch 5/5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.8824 - loss: 0.2898 - val_accuracy: 0.8751 - val_loss: 0.3106

# %%
acc = history_ltsm.history['accuracy']
val_acc = history_ltsm.history['val_accuracy']
loss = history_ltsm.history['loss']
val_loss = history_ltsm.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')

plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')

plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
model_bi = Sequential()

model_bi.add(Embedding(max_features, 32))
model_bi.add(Bidirectional(LSTM(32)))
model_bi.add(Dense(1, activation='sigmoid'))

model_bi.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history_bi = model_bi.fit(input_train, y_train, epochs=5, batch_size=128, validation_split=0.3)
# Out:
# Epoch 1/5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 9s 50ms/step - accuracy: 0.6031 - loss: 0.6467 - val_accuracy: 0.6723 - val_loss: 0.5948
# Epoch 2/5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.7958 - loss: 0.4489 - val_accuracy: 0.8461 - val_loss: 0.3664
# Epoch 3/5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - accuracy: 0.8572 - loss: 0.3495 - val_accuracy: 0.8455 - val_loss: 0.3635
# Epoch 4/5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.8734 - loss: 0.3188 - val_accuracy: 0.8695 - val_loss: 0.3121
# Epoch 5/5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - accuracy: 0.8818 - loss: 0.2966 - val_accuracy: 0.8685 - val_loss: 0.3101

# %%
acc = history_bi.history['accuracy']
val_acc = history_bi.history['val_accuracy']
loss = history_bi.history['loss']
val_loss = history_bi.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')

plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')

plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
model_drnn = Sequential()

model_drnn.add(Embedding(max_features, 32))
model_drnn.add(Bidirectional(LSTM(32, return_sequences=True)))
model_drnn.add(Bidirectional(LSTM(32)))
model_drnn.add(Dense(1, activation='sigmoid'))

model_drnn.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history_drnn = model_drnn.fit(input_train, y_train, epochs=5, batch_size=128, validation_split=0.3)
# Out:
# Epoch 1/5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 80ms/step - accuracy: 0.5894 - loss: 0.6520 - val_accuracy: 0.7699 - val_loss: 0.5028
# Epoch 2/5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.8025 - loss: 0.4442 - val_accuracy: 0.8439 - val_loss: 0.3703
# Epoch 3/5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.8513 - loss: 0.3542 - val_accuracy: 0.8627 - val_loss: 0.3328
# Epoch 4/5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - accuracy: 0.8803 - loss: 0.3020 - val_accuracy: 0.7991 - val_loss: 0.4411
# Epoch 5/5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - accuracy: 0.8981 - loss: 0.2593 - val_accuracy: 0.8387 - val_loss: 0.4054

# %%
acc = history_drnn.history['accuracy']
val_acc = history_drnn.history['val_accuracy']
loss = history_drnn.history['loss']
val_loss = history_drnn.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')

plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')

plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## Висновок:
#
# У ході роботи було протестовано чотири архітектури рекурентних мереж. SimpleRNN показала найгіршу здатність до узагальнення через проблему затухаючих градієнтів. Найкращі та найбільш стабільні результати продемонстрували LSTM та Bidirectional LSTM, досягнувши точності понад 87%. Двостороння модель показала себе краще в контексті стабільності втрат (loss), що підтверджує важливість аналізу тексту в обох напрямках для розуміння контексту відгуків. Глибока мережа (Deep RNN) виявилася схильною до нестабільності навчання, що вказує на надмірну складність моделі для даної кількості епох без додаткових методів регуляризації. Для подальшого покращення результату доцільно використовувати EarlyStopping та Dropout.
